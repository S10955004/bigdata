# %% [markdown]
# <a href="https://colab.research.google.com/github/S10955004/bigdata/blob/main/0330_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("rJava")
install.packages("jiebaR")
install.packages("tmcn")
install.packages("dplyr")
install.packages("lubridate")
install.packages("stringr")
install.packages("wordcloud")
install.packages("Rwordseg",repos="http://R-Forge.R-project.org")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘jiebaRD’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Warning message:
# “dependency ‘HMM’ is not available”
# Warning message in install.packages("Rwordseg", repos = "http://R-Forge.R-project.org"):
# “installation of package ‘Rwordseg’ had non-zero exit status”

# %%
library(dplyr)
library(lubridate)
library(stringr)
library(jiebaR)
library(wordcloud)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
#
# Attaching package: ‘lubridate’
#
#
# The following objects are masked from ‘package:base’:
#
#     date, intersect, setdiff, union
#
#
# Loading required package: jiebaRD
#
# Loading required package: RColorBrewer

# %%
#載入文字
content <-"膽紅素代謝出問題 可能刺激皮膚發癢那麼，肝臟有問題究竟會不會令人全身皮膚癢？什麼情況下醫師會懷疑皮膚癢與肝臟問題有關？肝臟負責膽紅素的代謝，當膽紅素代謝出問題，膽紅素無法順利經由肝臟排出，沉積在體內導致黃疸，就可能進而刺激皮膚發癢，所以像是有膽結石、肝硬化、肝癌等造成膽道阻塞的患者，的確可能會全身皮膚癢，但醫師不會光靠皮膚癢來診斷；同時，肝臟或其他全身性代謝物質（如尿毒）造成的「癢」常是全身性的，與一般人皮膚癢多為局部搔癢兼有紅疹也不同。自體免疫膽管炎也會皮膚癢有些病患如同文章一開頭案例故事中的敏芝， 除了皮膚癢、疲累， 更重要的是有黃疸，加上眼周出現膽固醇沉積造成的黃色瘤（Xanthelasma）， 這些症狀會讓肝膽專科醫師高度懷疑是罕見的「原發性膽汁性膽管炎」（Primary biliary cholangitis），可透過抽血檢查看「鹼性磷酸酶」（ALP）及丙麩氨酸轉化酶（γ-GT）是否升高及「抗粒腺體抗體」（AMA）是否陽性來確診。原發性膽汁性膽管炎是一種好發於中年女性的自體免疫疾病，因為肝臟末端的小膽道被 T淋巴球攻擊，膽汁無法順利排出，長期鬱積產生肝毒性，最終導致不可逆的肝硬化。一般抽血檢查就能診斷，少數症狀非典型例如鹼性磷酸酶升高但AMA 抗體非陽性的病人，可以考慮接受肝臟穿刺檢查，進一步確診或評估疾病嚴重程度。隨著藥物發展，目前已經能有效治療，尤其早期治療效果良好。哪些皮膚問題也可能與肝臟有關除了癢，以下幾種皮膚問題也可能與肝臟疾病有關：膚色改變：如黃疸或色素沉著。皮膚血管異常：如肝硬化病人可能會有蜘蛛痣（好發於面部、上胸部）、腹壁靜脈曲張、手掌紅斑等。皮疹：如不容易消退的蕁麻疹、血管神經性水腫、小腿潰瘍。因神經內分泌激素在肝硬化狀況下代謝較慢導致濃度較高，及肝炎易引發自體免疫抗體，導致一系列皮膚血管併發症。指甲變化：有些肝硬化或肝炎病患會有灰指甲、指甲脆弱、杵狀指、線狀黑甲等
# %%
cutter[content]
# Out:
#   [1] "膽紅素"        "代謝"          "出"            "問題"
#   [5] "可能"          "刺激"          "皮膚"          "發癢"
#   [9] "那麼"          "肝臟"          "有"            "問題"
#  [13] "究竟"          "會"            "不會"          "令人"
#  [17] "全身"          "皮膚癢"        "什麼"          "情況"
#  [21] "下"            "醫師"          "會"            "懷疑"
#  [25] "皮膚癢"        "與"            "肝臟"          "問題"
#  [29] "有關"          "肝臟"          "負責"          "膽紅素"
#  [33] "的"            "代謝"          "當"            "膽紅素"
#  [37] "代謝"          "出"            "問題"          "膽紅素"
#  [41] "無法"          "順利"          "經由"          "肝臟"
#  [45] "排出"          "沉積"          "在"            "體內"
#  [49] "導致"          "黃疸"          "就"            "可能"
#  [53] "進而"          "刺激"          "皮膚"          "發癢"
#  [57] "所以"          "像是"          "有"            "膽結石"
#  [61] "肝硬化"        "肝癌"          "等"            "造成"
#  [65] "膽道"          "阻塞"          "的"            "患者"
# ...

# %%
new_words <-c("肝炎","免疫系統","皮膚病症")
#一次只能加入一個詞,常常需要搭配迴圈使用
for(i in 1:length(new_words)){new_user_word(cutter,new_words[i])}
content <- str_remove_all(content,"[0-9a-zA-Z]+?")
cutter[content]
# Out:
#   [1] "膽紅素"   "代謝"     "出"       "問題"     "可能"     "刺激"
#   [7] "皮膚"     "發癢"     "那麼"     "肝臟"     "有"       "問題"
#  [13] "究竟"     "會"       "不會"     "令人"     "全身"     "皮膚癢"
#  [19] "什麼"     "情況"     "下"       "醫師"     "會"       "懷疑"
#  [25] "皮膚癢"   "與"       "肝臟"     "問題"     "有關"     "肝臟"
#  [31] "負責"     "膽紅素"   "的"       "代謝"     "當"       "膽紅素"
#  [37] "代謝"     "出"       "問題"     "膽紅素"   "無法"     "順利"
#  [43] "經由"     "肝臟"     "排出"     "沉積"     "在"       "體內"
#  [49] "導致"     "黃疸"     "就"       "可能"     "進而"     "刺激"
#  [55] "皮膚"     "發癢"     "所以"     "像是"     "有"       "膽結石"
#  [61] "肝硬化"   "肝癌"     "等"       "造成"     "膽道"     "阻塞"
#  [67] "的"       "患者"     "的確"     "可能"     "會"       "全身"
#  [73] "皮膚癢"   "但"       "醫師"     "不會"     "光靠"     "皮膚癢"
#  [79] "來"       "診斷"     "同時"     "肝臟"     "或"       "其他"
#  [85] "全身性"   "代謝"     "物質"     "如"       "尿毒"     "造成"
#  [91] "的"       "癢"       "常"       "是"       "全身性"   "的"
# ...

# %%
new_words <-c("肝炎","免疫系統","皮膚病症")
writeLines(new_words,"new_words.txt")
stop_words <-c("在","之","更","個","未","而","也","的","與","有","是","會")
writeLines(stop_words,"stop_words.txt")

# %%
cutter<-worker(user="new_words.txt",stop_word="stop_words.txt",
bylines=FALSE)
seg_words<-cutter[content]
seg_words
# Out:
#   [1] "膽紅素"   "代謝"     "出"       "問題"     "可能"     "刺激"
#   [7] "皮膚"     "發癢"     "那麼"     "肝臟"     "問題"     "究竟"
#  [13] "不會"     "令人"     "全身"     "皮膚癢"   "什麼"     "情況"
#  [19] "下"       "醫師"     "懷疑"     "皮膚癢"   "肝臟"     "問題"
#  [25] "有關"     "肝臟"     "負責"     "膽紅素"   "代謝"     "當"
#  [31] "膽紅素"   "代謝"     "出"       "問題"     "膽紅素"   "無法"
#  [37] "順利"     "經由"     "肝臟"     "排出"     "沉積"     "體內"
#  [43] "導致"     "黃疸"     "就"       "可能"     "進而"     "刺激"
#  [49] "皮膚"     "發癢"     "所以"     "像是"     "膽結石"   "肝硬化"
#  [55] "肝癌"     "等"       "造成"     "膽道"     "阻塞"     "患者"
#  [61] "的確"     "可能"     "全身"     "皮膚癢"   "但"       "醫師"
#  [67] "不會"     "光靠"     "皮膚癢"   "來"       "診斷"     "同時"
#  [73] "肝臟"     "或"       "其他"     "全身性"   "代謝"     "物質"
#  [79] "如"       "尿毒"     "造成"     "癢"       "常"       "全身性"
#  [85] "一般"     "人"       "皮膚癢"   "多為"     "局部"     "搔癢"
#  [91] "兼有"     "紅疹"     "不同"     "自體"     "免疫"     "膽管炎"
#  [97] "皮膚癢"   "有些"     "病患"     "如同"     "文章"     "一"
# ...

# %%
#計算詞彙頻率
txt_freq<-freq(seg_words)
#由大到小排列
txt_freq<-arrange(txt_freq,desc(freq))
#檢查前5名
head(txt_freq)
# Out:
#   char   freq
# 1 皮膚   18
# 2 肝臟   16
# 3 問題   14
# 4 球蛋白 13
# 5 可能   11
# 6 皮膚癢 10

# %%
par(family=("Microsoft YaHei"))#wordcloud需要定義字體,不然會無法顯示中文
#文字雲(pkg:wordcloud)
wordcloud(txt_freq$char,txt_freq$freq,min.freq=2,random.order=F,
ordered.colors=F,colors=rainbow(nrow(txt_freq)))
# Out:
# Warning message in strwidth(words[i], cex = size[i], ...):
# “font family 'Microsoft YaHei' not found, will use 'wqy-microhei' instead”
# Warning message in strheight(words[i], cex = size[i], ...):
# “font family 'Microsoft YaHei' not found, will use 'sans' instead”
# Warning message in text.default(x1, y1, words[i], cex = size[i], offset = 0, srt = rotWord * :
# “font family 'Microsoft YaHei' not found, will use 'wqy-microhei' instead”
# Warning message in text.default(x1, y1, words[i], cex = size[i], offset = 0, srt = rotWord * :
# “font family 'Microsoft YaHei' not found, will use 'wqy-microhei' instead”
# Warning message in text.default(x1, y1, words[i], cex = size[i], offset = 0, srt = rotWord * :
# “font family 'Microsoft YaHei' not found, will use 'wqy-microhei' instead”
# Warning message in text.default(x1, y1, words[i], cex = size[i], offset = 0, srt = rotWord * :
# “font family 'Microsoft YaHei' not found, will use 'wqy-microhei' instead”
# ...

# %%
install.packages("showtext")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘sysfonts’, ‘showtextdb’

# %%
library(showtext)
# Out:
# Loading required package: sysfonts
#
# Loading required package: showtextdb

# %%
showtext.auto(enable=TRUE)
# Out:
# 'showtext.auto()' is now renamed to 'showtext_auto()'
# The old version still works, but consider using the new function in future code
